# %%
import pandas as pd
df = pd.read_csv('/content/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.drop(columns=['id'] , inplace=True )
df.drop(columns='Unnamed: 32' , inplace=True )

# %%
df.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
import seaborn as sns

# %%
# sns.pairplot(df[df.columns], kind="kde", diag_kind="hist")

# %%
sns.countplot(x=df['diagnosis'])
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler , LabelEncoder
from sklearn.model_selection import train_test_split

le = LabelEncoder()
df['diagnosis'] = le.fit_transform(df['diagnosis'])

x = df.drop(columns='diagnosis')
y = df['diagnosis']

x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=42)

# %%
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %%
df['diagnosis']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
df['diagnosis'].unique()
# Out:
# array([1, 0])

# %%
le.classes_
# Out:
# array(['B', 'M'], dtype=object)

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
#

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(x_train , y_train)

model.score(x_test , y_test)
# Out:
# 0.9736842105263158

# %%
from sklearn.metrics  import confusion_matrix , classification_report , accuracy_score , precision_score , recall_score , f1_score , roc_auc_score

y_pred = model.predict(x_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.9736842105263158

# %%
cm = confusion_matrix(y_test , y_pred)

sns.heatmap(cm , annot=True , fmt='d' , cmap='Blues')
# Out:
# <Axes: >

# %%
recall_score(y_test , y_pred)
# Out:
# 0.9534883720930233

# %%
precision_score(y_test , y_pred)
# Out:
# 0.9761904761904762

# %%
f1_score(y_test , y_pred)
# Out:
# 0.9647058823529412

# %%
auc = roc_auc_score(y_test , y_pred)

# %%
auc
# Out:
# np.float64(0.9697019325253848)

# %%
# import numpy as np

# Saisie utilisateur
raw = input("Enter the values of patient separated by commas : ")

# Transformer en liste de nombres
values = np.array(raw.split(','), dtype=float)

# Créer DataFrame dans le même ordre que df
data = pd.DataFrame([values], columns=df.columns[1:])
# (on retire 'diagnosis' car c'est la target)

# Normaliser
data_scaled = scaler.transform(data)

# Prédiction
value = model.predict(data_scaled)[0]

if value == 0:
    print("The patient is Benign")
else:
    print("The patient is Malignant")
# Out:
# Enter the values of patient separated by commas : 13.54,14.36,87.46,566.3,0.09779,0.08129,0.06664,0.04781,0.1885,0.05766,0.2699,0.7886,2.058,23.56,0.008462,0.0146,0.02387,0.01315,0.0198,0.0023,15.11,19.26,99.7,711.2,0.144,0.1773,0.239,0.1288,0.2977,0.07259
# The patient is Benign

# %%
nouveau_patient = {
    'radius_mean': 14.2,
    'texture_mean': 20.5,
    'perimeter_mean': 92.3,
    'area_mean': 580.2,
    'smoothness_mean': 0.095,
    'compactness_mean': 0.102,
    'concavity_mean': 0.085,
    'concave points_mean': 0.050,
    'symmetry_mean': 0.185,
    'fractal_dimension_mean': 0.060,
    'radius_se': 0.45,
    'texture_se': 1.05,
    'perimeter_se': 3.25,
    'area_se': 45.9,
    'smoothness_se': 0.005,
    'compactness_se': 0.015,
    'concavity_se': 0.020,
    'concave points_se': 0.010,
    'symmetry_se': 0.025,
    'fractal_dimension_se': 0.003,
    'radius_worst': 16.9,
    'texture_worst': 28.3,
    'perimeter_worst': 110.2,
    'area_worst': 870.4,
    'smoothness_worst': 0.150,
    'compactness_worst': 0.210,
    'concavity_worst': 0.250,
    'concave points_worst': 0.120,
    'symmetry_worst': 0.260,
    'fractal_dimension_worst': 0.080
}

# %%
nouveau_patient.values()
# Out:
# dict_values([14.2, 20.5, 92.3, 580.2, 0.095, 0.102, 0.085, 0.05, 0.185, 0.06, 0.45, 1.05, 3.25, 45.9, 0.005, 0.015, 0.02, 0.01, 0.025, 0.003, 16.9, 28.3, 110.2, 870.4, 0.15, 0.21, 0.25, 0.12, 0.26, 0.08])
